# %% [markdown]
# # **Imports**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# importing required libraries
import numpy as np
import pandas as pd
import pickle # saving and loading trained model
from os import path

# importing required libraries for normalizing data
from sklearn import preprocessing
from sklearn.preprocessing import StandardScaler

# importing library for plotting
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn import metrics
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve, auc

import tensorflow as tf
from tensorflow.keras.utils import to_categorical

from keras.layers import Dense, LSTM, MaxPool1D, Flatten, Dropout # importing dense layer
from keras.models import Sequential #importing Sequential layer
from keras.layers import Input
from keras.models import Model
# representation of model layers
# from keras.utils.vis_utils import plot_model

# %% [markdown]
# ## Reading Data

# %%
feature=["duration","protocol_type","service","flag","src_bytes","dst_bytes","land","wrong_fragment","urgent","hot",
          "num_failed_logins","logged_in","num_compromised","root_shell","su_attempted","num_root","num_file_creations","num_shells",
          "num_access_files","num_outbound_cmds","is_host_login","is_guest_login","count","srv_count","serror_rate","srv_serror_rate",
          "rerror_rate","srv_rerror_rate","same_srv_rate","diff_srv_rate","srv_diff_host_rate","dst_host_count","dst_host_srv_count",
          "dst_host_same_srv_rate","dst_host_diff_srv_rate","dst_host_same_src_port_rate","dst_host_srv_diff_host_rate","dst_host_serror_rate",
          "dst_host_srv_serror_rate","dst_host_rerror_rate","dst_host_srv_rerror_rate","label","difficulty"]

# %%
train='/content/drive/MyDrive/5566/KDDTrain+.txt'
test='/content/drive/MyDrive/5566/KDDTest+.txt'
test21='/content/drive/MyDrive/5566/KDDTest-21.txt'
train_data=pd.read_csv(train,names=feature)
test_data=pd.read_csv(test,names=feature)
test_data21 = pd.read_csv(test21, names= feature)
data= pd.concat([train_data, test_data], ignore_index=True)

# %%
data
# Out:
#         duration protocol_type   service flag  src_bytes  dst_bytes  land  \
# 0              0           tcp  ftp_data   SF        491          0     0
# 1              0           udp     other   SF        146          0     0
# 2              0           tcp   private   S0          0          0     0
# 3              0           tcp      http   SF        232       8153     0
# 4              0           tcp      http   SF        199        420     0
# ...          ...           ...       ...  ...        ...        ...   ...
# 148512         0           tcp      smtp   SF        794        333     0
# 148513         0           tcp      http   SF        317        938     0
# 148514         0           tcp      http   SF      54540       8314     0
# 148515         0           udp  domain_u   SF         42         42     0
# 148516         0           tcp    sunrpc  REJ          0          0     0
#
#         wrong_fragment  urgent  hot  ...  dst_host_same_srv_rate  \
# 0                    0       0    0  ...                    0.17
# 1                    0       0    0  ...                    0.00
# 2                    0       0    0  ...                    0.10
# 3                    0       0    0  ...                    1.00
# 4                    0       0    0  ...                    1.00
# ...                ...     ...  ...  ...                     ...
# 148512               0       0    0  ...                    0.72
# 148513               0       0    0  ...                    1.00
# 148514               0       0    2  ...                    1.00
# 148515               0       0    0  ...                    0.99
# 148516               0       0    0  ...                    0.08
#
#         dst_host_diff_srv_rate  dst_host_same_src_port_rate  \
# 0                         0.03                         0.17
# 1                         0.60                         0.88
# 2                         0.05                         0.00
# 3                         0.00                         0.03
# 4                         0.00                         0.00
# ...                        ...                          ...
# 148512                    0.06                         0.01
# 148513                    0.00                         0.01
# 148514                    0.00                         0.00
# 148515                    0.01                         0.00
# 148516                    0.03                         0.00
#
#         dst_host_srv_diff_host_rate  dst_host_serror_rate  \
# 0                              0.00                  0.00
# 1                              0.00                  0.00
# 2                              0.00                  1.00
# 3                              0.04                  0.03
# 4                              0.00                  0.00
# ...                             ...                   ...
# 148512                         0.01                  0.01
# 148513                         0.01                  0.01
# 148514                         0.00                  0.00
# 148515                         0.00                  0.00
# 148516                         0.00                  0.00
#
#         dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                           0.00                  0.05
# 1                           0.00                  0.00
# 2                           1.00                  0.00
# 3                           0.01                  0.00
# 4                           0.00                  0.00
# ...                          ...                   ...
# 148512                      0.00                  0.00
# 148513                      0.00                  0.00
# 148514                      0.00                  0.07
# 148515                      0.00                  0.00
# 148516                      0.00                  0.44
#
#         dst_host_srv_rerror_rate    label  difficulty
# 0                           0.00   normal          20
# 1                           0.00   normal          15
# 2                           0.00  neptune          19
# 3                           0.01   normal          21
# 4                           0.00   normal          21
# ...                          ...      ...         ...
# 148512                      0.00   normal          21
# 148513                      0.00   normal          21
# 148514                      0.07     back          15
# 148515                      0.00   normal          21
# 148516                      1.00    mscan          14
#
# [148517 rows x 43 columns]

# %%
# remove attribute 'difficulty_level'
data.drop(['difficulty'],axis=1,inplace=True)

# %% [markdown]
# ## Exploring Data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148517 entries, 0 to 148516
# Data columns (total 42 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   duration                     148517 non-null  int64
#  1   protocol_type                148517 non-null  object
#  2   service                      148517 non-null  object
#  3   flag                         148517 non-null  object
#  4   src_bytes                    148517 non-null  int64
#  5   dst_bytes                    148517 non-null  int64
#  6   land                         148517 non-null  int64
#  7   wrong_fragment               148517 non-null  int64
#  8   urgent                       148517 non-null  int64
#  9   hot                          148517 non-null  int64
#  10  num_failed_logins            148517 non-null  int64
#  11  logged_in                    148517 non-null  int64
#  12  num_compromised              148517 non-null  int64
#  13  root_shell                   148517 non-null  int64
#  14  su_attempted                 148517 non-null  int64
#  15  num_root                     148517 non-null  int64
#  16  num_file_creations           148517 non-null  int64
#  17  num_shells                   148517 non-null  int64
#  18  num_access_files             148517 non-null  int64
#  19  num_outbound_cmds            148517 non-null  int64
#  20  is_host_login                148517 non-null  int64
#  21  is_guest_login               148517 non-null  int64
#  22  count                        148517 non-null  int64
#  23  srv_count                    148517 non-null  int64
#  24  serror_rate                  148517 non-null  float64
#  25  srv_serror_rate              148517 non-null  float64
#  26  rerror_rate                  148517 non-null  float64
#  27  srv_rerror_rate              148517 non-null  float64
#  28  same_srv_rate                148517 non-null  float64
#  29  diff_srv_rate                148517 non-null  float64
#  30  srv_diff_host_rate           148517 non-null  float64
#  31  dst_host_count               148517 non-null  int64
#  32  dst_host_srv_count           148517 non-null  int64
#  33  dst_host_same_srv_rate       148517 non-null  float64
#  34  dst_host_diff_srv_rate       148517 non-null  float64
#  35  dst_host_same_src_port_rate  148517 non-null  float64
#  36  dst_host_srv_diff_host_rate  148517 non-null  float64
#  37  dst_host_serror_rate         148517 non-null  float64
#  38  dst_host_srv_serror_rate     148517 non-null  float64
#  39  dst_host_rerror_rate         148517 non-null  float64
#  40  dst_host_srv_rerror_rate     148517 non-null  float64
#  41  label                        148517 non-null  object
# dtypes: float64(15), int64(23), object(4)
# memory usage: 47.6+ MB

# %%
data.describe().T
# Out:
#                                 count          mean           std  min    25%  \
# duration                     148517.0    276.779305  2.460683e+03  0.0   0.00
# src_bytes                    148517.0  40227.949299  5.409612e+06  0.0   0.00
# dst_bytes                    148517.0  17088.853593  3.703525e+06  0.0   0.00
# land                         148517.0      0.000215  1.467714e-02  0.0   0.00
# wrong_fragment               148517.0      0.020523  2.400691e-01  0.0   0.00
# urgent                       148517.0      0.000202  1.941708e-02  0.0   0.00
# hot                          148517.0      0.189379  2.013160e+00  0.0   0.00
# num_failed_logins            148517.0      0.004323  7.224823e-02  0.0   0.00
# logged_in                    148517.0      0.402789  4.904606e-01  0.0   0.00
# num_compromised              148517.0      0.255062  2.223137e+01  0.0   0.00
# root_shell                   148517.0      0.001508  3.880696e-02  0.0   0.00
# su_attempted                 148517.0      0.000976  4.238907e-02  0.0   0.00
# num_root                     148517.0      0.273726  2.268902e+01  0.0   0.00
# num_file_creations           148517.0      0.012073  5.178631e-01  0.0   0.00
# num_shells                   148517.0      0.000525  2.770051e-02  0.0   0.00
# num_access_files             148517.0      0.004013  9.525663e-02  0.0   0.00
# num_outbound_cmds            148517.0      0.000000  0.000000e+00  0.0   0.00
# is_host_login                148517.0      0.000081  8.988484e-03  0.0   0.00
# is_guest_login               148517.0      0.012308  1.102585e-01  0.0   0.00
# count                        148517.0     83.336561  1.167607e+02  0.0   2.00
# srv_count                    148517.0     28.251937  7.536963e+01  0.0   2.00
# serror_rate                  148517.0      0.256925  4.319178e-01  0.0   0.00
# srv_serror_rate              148517.0      0.255337  4.325783e-01  0.0   0.00
# rerror_rate                  148517.0      0.137947  3.393872e-01  0.0   0.00
# srv_rerror_rate              148517.0      0.138487  3.417829e-01  0.0   0.00
# same_srv_rate                148517.0      0.672983  4.365437e-01  0.0   0.10
# diff_srv_rate                148517.0      0.067761  1.946658e-01  0.0   0.00
# srv_diff_host_rate           148517.0      0.097441  2.588856e-01  0.0   0.00
# dst_host_count               148517.0    183.928042  9.852833e+01  0.0  87.00
# dst_host_srv_count           148517.0    119.462661  1.112323e+02  0.0  11.00
# dst_host_same_srv_rate       148517.0      0.534521  4.480612e-01  0.0   0.05
# dst_host_diff_srv_rate       148517.0      0.084103  1.941020e-01  0.0   0.00
# dst_host_same_src_port_rate  148517.0      0.145932  3.086376e-01  0.0   0.00
# dst_host_srv_diff_host_rate  148517.0      0.030584  1.089751e-01  0.0   0.00
# dst_host_serror_rate         148517.0      0.256122  4.284996e-01  0.0   0.00
# dst_host_srv_serror_rate     148517.0      0.251304  4.297194e-01  0.0   0.00
# dst_host_rerror_rate         148517.0      0.136220  3.227411e-01  0.0   0.00
# dst_host_srv_rerror_rate     148517.0      0.136397  3.352823e-01  0.0   0.00
#
#                                 50%     75%           max
# duration                       0.00    0.00  5.771500e+04
# src_bytes                     44.00  278.00  1.379964e+09
# dst_bytes                      0.00  571.00  1.309937e+09
# land                           0.00    0.00  1.000000e+00
# wrong_fragment                 0.00    0.00  3.000000e+00
# urgent                         0.00    0.00  3.000000e+00
# hot                            0.00    0.00  1.010000e+02
# num_failed_logins              0.00    0.00  5.000000e+00
# logged_in                      0.00    1.00  1.000000e+00
# num_compromised                0.00    0.00  7.479000e+03
# root_shell                     0.00    0.00  1.000000e+00
# su_attempted                   0.00    0.00  2.000000e+00
# num_root                       0.00    0.00  7.468000e+03
# num_file_creations             0.00    0.00  1.000000e+02
# num_shells                     0.00    0.00  5.000000e+00
# num_access_files               0.00    0.00  9.000000e+00
# num_outbound_cmds              0.00    0.00  0.000000e+00
# is_host_login                  0.00    0.00  1.000000e+00
# is_guest_login                 0.00    0.00  1.000000e+00
# count                         13.00  141.00  5.110000e+02
# srv_count                      7.00   17.00  5.110000e+02
# serror_rate                    0.00    0.85  1.000000e+00
# srv_serror_rate                0.00    0.91  1.000000e+00
# rerror_rate                    0.00    0.00  1.000000e+00
# srv_rerror_rate                0.00    0.00  1.000000e+00
# same_srv_rate                  1.00    1.00  1.000000e+00
# diff_srv_rate                  0.00    0.06  1.000000e+00
# srv_diff_host_rate             0.00    0.00  1.000000e+00
# dst_host_count               255.00  255.00  2.550000e+02
# dst_host_srv_count            72.00  255.00  2.550000e+02
# dst_host_same_srv_rate         0.60    1.00  1.000000e+00
# dst_host_diff_srv_rate         0.02    0.07  1.000000e+00
# dst_host_same_src_port_rate    0.00    0.05  1.000000e+00
# dst_host_srv_diff_host_rate    0.00    0.01  1.000000e+00
# dst_host_serror_rate           0.00    0.60  1.000000e+00
# dst_host_srv_serror_rate       0.00    0.50  1.000000e+00
# dst_host_rerror_rate           0.00    0.00  1.000000e+00
# dst_host_srv_rerror_rate       0.00    0.00  1.000000e+00

# %%
# number of attack labels
data['label'].value_counts()
# Out:
# label
# normal             77054
# neptune            45871
# satan               4368
# ipsweep             3740
# smurf               3311
# portsweep           3088
# nmap                1566
# back                1315
# guess_passwd        1284
# mscan                996
# warezmaster          964
# teardrop             904
# warezclient          890
# apache2              737
# processtable         685
# snmpguess            331
# saint                319
# mailbomb             293
# pod                  242
# snmpgetattack        178
# httptunnel           133
# buffer_overflow       50
# land                  25
# multihop              25
# rootkit               23
# named                 17
# ps                    15
# sendmail              14
# xterm                 13
# imap                  12
# ftp_write             11
# loadmodule            11
# xlock                  9
# phf                    6
# perl                   5
# xsnoop                 4
# spy                    2
# worm                   2
# sqlattack              2
# udpstorm               2
# Name: count, dtype: int64

# %%
# Redistribute across common attack class
def change_label(df):
  df.label.replace(['apache2','back','land','neptune','mailbomb','pod','processtable','smurf','teardrop','udpstorm','worm'],'Dos',inplace=True)
  df.label.replace(['ftp_write','guess_passwd','httptunnel','imap','multihop','named','phf','sendmail','snmpgetattack','snmpguess','spy','warezclient','warezmaster','xlock','xsnoop'],'R2L',inplace=True)
  df.label.replace(['ipsweep','mscan','nmap','portsweep','saint','satan'],'Probe',inplace=True)
  df.label.replace(['buffer_overflow','loadmodule','perl','ps','rootkit','sqlattack','xterm'],'U2R',inplace=True)

# %%
change_label(data)

# %%
# distribution of attack classes
data.label.value_counts()
# Out:
# label
# normal    77054
# Dos       53387
# Probe     14077
# R2L        3880
# U2R         119
# Name: count, dtype: int64

# %% [markdown]
# ### Protocol

# %%
# creating a dataframe with multi-class labels (Dos,Probe,R2L,U2R,normal)
label = pd.DataFrame(data.label)

# %%
# using standard scaler for normalizing
std_scaler = StandardScaler()
def standardization(df,col):
    for i in col:
        arr = df[i]
        arr = np.array(arr)
        df[i] = std_scaler.fit_transform(arr.reshape(len(arr),1))
    return df

numeric_col = data.select_dtypes(include='number').columns
data = standardization(data,numeric_col)

# %%
# label encoding (0,1,2,3,4) multi-class labels (Dos,normal,Probe,R2L,U2R)
le2 = preprocessing.LabelEncoder()
enc_label = label.apply(le2.fit_transform)
data['intrusion'] = enc_label
print(data.shape)
data
# Out:
# (148517, 43)
#         duration protocol_type   service flag  src_bytes  dst_bytes     land  \
# 0      -0.112481           tcp  ftp_data   SF  -0.007346  -0.004614 -0.01468
# 1      -0.112481           udp     other   SF  -0.007409  -0.004614 -0.01468
# 2      -0.112481           tcp   private   S0  -0.007436  -0.004614 -0.01468
# 3      -0.112481           tcp      http   SF  -0.007394  -0.002413 -0.01468
# 4      -0.112481           tcp      http   SF  -0.007400  -0.004501 -0.01468
# ...          ...           ...       ...  ...        ...        ...      ...
# 148512 -0.112481           tcp      smtp   SF  -0.007290  -0.004524 -0.01468
# 148513 -0.112481           tcp      http   SF  -0.007378  -0.004361 -0.01468
# 148514 -0.112481           tcp      http   SF   0.002646  -0.002369 -0.01468
# 148515 -0.112481           udp  domain_u   SF  -0.007429  -0.004603 -0.01468
# 148516 -0.112481           tcp    sunrpc  REJ  -0.007436  -0.004614 -0.01468
#
#         wrong_fragment    urgent       hot  ...  dst_host_same_srv_rate  \
# 0            -0.085488 -0.010403 -0.094071  ...               -0.813554
# 1            -0.085488 -0.010403 -0.094071  ...               -1.192968
# 2            -0.085488 -0.010403 -0.094071  ...               -0.969783
# 3            -0.085488 -0.010403 -0.094071  ...                1.038878
# 4            -0.085488 -0.010403 -0.094071  ...                1.038878
# ...                ...       ...       ...  ...                     ...
# 148512       -0.085488 -0.010403 -0.094071  ...                0.413961
# 148513       -0.085488 -0.010403 -0.094071  ...                1.038878
# 148514       -0.085488 -0.010403  0.899396  ...                1.038878
# 148515       -0.085488 -0.010403 -0.094071  ...                1.016560
# 148516       -0.085488 -0.010403 -0.094071  ...               -1.014420
#
#         dst_host_diff_srv_rate  dst_host_same_src_port_rate  \
# 0                    -0.278736                     0.077981
# 1                     2.657874                     2.378421
# 2                    -0.175697                    -0.472829
# 3                    -0.433294                    -0.375627
# 4                    -0.433294                    -0.472829
# ...                        ...                          ...
# 148512               -0.124178                    -0.440428
# 148513               -0.433294                    -0.440428
# 148514               -0.433294                    -0.472829
# 148515               -0.381775                    -0.472829
# 148516               -0.278736                    -0.472829
#
#         dst_host_srv_diff_host_rate  dst_host_serror_rate  \
# 0                         -0.280650             -0.597720
# 1                         -0.280650             -0.597720
# 2                         -0.280650              1.736012
# 3                          0.086408             -0.527708
# 4                         -0.280650             -0.597720
# ...                             ...                   ...
# 148512                    -0.188885             -0.574382
# 148513                    -0.188885             -0.574382
# 148514                    -0.280650             -0.597720
# 148515                    -0.280650             -0.597720
# 148516                    -0.280650             -0.597720
#
#         dst_host_srv_serror_rate  dst_host_rerror_rate  \
# 0                      -0.584813             -0.267151
# 1                      -0.584813             -0.422074
# 2                       1.742295             -0.422074
# 3                      -0.561542             -0.422074
# 4                      -0.584813             -0.422074
# ...                          ...                   ...
# 148512                 -0.584813             -0.422074
# 148513                 -0.584813             -0.422074
# 148514                 -0.584813             -0.205182
# 148515                 -0.584813             -0.422074
# 148516                 -0.584813              0.941252
#
#         dst_host_srv_rerror_rate   label  intrusion
# 0                      -0.406815  normal          4
# 1                      -0.406815  normal          4
# 2                      -0.406815     Dos          0
# 3                      -0.376989  normal          4
# 4                      -0.406815  normal          4
# ...                          ...     ...        ...
# 148512                 -0.406815  normal          4
# 148513                 -0.406815  normal          4
# 148514                 -0.198035     Dos          0
# 148515                 -0.406815  normal          4
# 148516                  2.575756   Probe          1
#
# [148517 rows x 43 columns]

# %%
data.drop(labels= ['label'], axis=1, inplace=True)
print(data.shape)
# Out:
# (148517, 42)

# %%
# one-hot-encoding categorical columns
data = pd.get_dummies(data,columns=['protocol_type','service','flag'],prefix="",prefix_sep="")
print(data.shape)
# Out:
# (148517, 123)

# %%
y_data= data['intrusion']
X_data= data.drop(labels=['intrusion'], axis=1)

print('X_train has shape:',X_data.shape,'\ny_train has shape:',y_data.shape)
# Out:
# X_train has shape: (148517, 122)
# y_train has shape: (148517,)

# %%
from sklearn.preprocessing import LabelBinarizer
y_data = LabelBinarizer().fit_transform(y_data)

X_data=np.array(X_data)
y_data=np.array(y_data)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_data,y_data, test_size=0.20, random_state=42)
print(X_train.shape,'\n',X_test.shape)
# Out:
# (118813, 122)
#  (29704, 122)

# %%
# reshape input to be [samples, time steps, features]
X_train = np.reshape(X_train, ( X_train.shape[0], 1 , X_train.shape[1] ))
X_test = np.reshape(X_test, ( X_test.shape[0], 1,  X_test.shape[1] ))

# %%
# %matplotlib inline
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.metrics import classification_report, confusion_matrix
import tensorflow as tf
import numpy as np


from tensorflow.keras import layers
import time


from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder

# %%
from tensorflow.keras.models import Model
from tensorflow.keras import layers

n_features = X_train.shape[2]  # Assuming the last dimension is the number of features

class AnomalyDetector(Model):
    def __init__(self):
        super(AnomalyDetector, self).__init__()
        self.encoder = tf.keras.Sequential([
            layers.Input(shape=(1, n_features)),  # Input layer with the correct shape
            layers.Flatten(),  # Flatten the input
            layers.Dense(128, activation="relu"),
            layers.Dense(64, activation="relu"),
            layers.Dense(32, activation="relu")
        ])

        self.decoder = tf.keras.Sequential([
            layers.Dense(64, activation="relu"),
            layers.Dense(128, activation="relu"),
            layers.Dense(5, activation="linear")
        ])

    def call(self, x):
        encoded = self.encoder(x)
        decoded = self.decoder(encoded)
        return decoded

autoencoder = AnomalyDetector()

# %%
from keras.layers import Input, Dense
from keras.models import Model

n_features =X_train.shape[2]
# Define the input shape
input_shape = (n_features,)

# Define the encoder architecture
input_layer = Input(shape=input_shape)
encoded = Dense(128, activation='relu')(input_layer)
encoded = Dense(64, activation='relu')(encoded)
encoded = Dense(32, activation='relu')(encoded)

# Define the decoder architecture
decoded = Dense(64, activation='relu')(encoded)
decoded = Dense(128, activation='relu')(decoded)
output_layer = Dense(5, activation='linear')(decoded)

# Define the autoencoder model
autoencoder = Model(input_layer, output_layer)

# %%
# defining loss function, optimizer, metrics and then compiling model
autoencoder.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
# summary of model layers
autoencoder.summary()
# Out:
# Model: "model_5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_8 (InputLayer)        [(None, 122)]             0
#
#  dense_74 (Dense)            (None, 128)               15744
#
#  dense_75 (Dense)            (None, 64)                8256
#
#  dense_76 (Dense)            (None, 32)                2080
#
#  dense_77 (Dense)            (None, 64)                2112
#
#  dense_78 (Dense)            (None, 128)               8320
#
#  dense_79 (Dense)            (None, 5)                 645
#
# =================================================================
# Total params: 37157 (145.14 KB)
# Trainable params: 37157 (145.14 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
print(X_train.dtype, y_train.dtype)
# Out:
# float32 int64

# %%
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
import numpy as np

# Assuming X_train is your original data
# Convert object type array to float32
X_train = X_train.astype(np.float32)

# %%
X_train_reshaped = np.reshape(X_train, (-1, X_train.shape[2]))

# %%
# training the model on training dataset
history = autoencoder.fit(X_train_reshaped, y_train, epochs=100, batch_size=5000,validation_split=0.2)
# Out:
# Epoch 1/100
# 20/20 [==============================] - 2s 16ms/step - loss: 6.2056 - accuracy: 0.5851 - val_loss: 14.3040 - val_accuracy: 0.5448
# Epoch 2/100
# 20/20 [==============================] - 0s 7ms/step - loss: 10.4357 - accuracy: 0.5358 - val_loss: 9.9186 - val_accuracy: 0.5656
# Epoch 3/100
# 20/20 [==============================] - 0s 8ms/step - loss: 9.5329 - accuracy: 0.5766 - val_loss: 10.8990 - val_accuracy: 0.5772
# Epoch 4/100
# 20/20 [==============================] - 0s 8ms/step - loss: 11.2886 - accuracy: 0.5761 - val_loss: 11.6134 - val_accuracy: 0.5715
# Epoch 5/100
# 20/20 [==============================] - 0s 8ms/step - loss: 11.6348 - accuracy: 0.5716 - val_loss: 11.7812 - val_accuracy: 0.5656
# Epoch 6/100
# 20/20 [==============================] - 0s 8ms/step - loss: 11.6223 - accuracy: 0.5624 - val_loss: 11.6014 - val_accuracy: 0.5551
# Epoch 7/100
# 20/20 [==============================] - 0s 7ms/step - loss: 11.4066 - accuracy: 0.5567 - val_loss: 10.9187 - val_accuracy: 0.5465
# Epoch 8/100
# 20/20 [==============================] - 0s 8ms/step - loss: 10.7297 - accuracy: 0.5500 - val_loss: 10.6629 - val_accuracy: 0.5461
# Epoch 9/100
# 20/20 [==============================] - 0s 8ms/step - loss: 10.6379 - accuracy: 0.5506 - val_loss: 10.6580 - val_accuracy: 0.5471
# Epoch 10/100
# 20/20 [==============================] - 0s 7ms/step - loss: 10.6224 - accuracy: 0.5517 - val_loss: 10.6308 - val_accuracy: 0.5487
# Epoch 11/100
# 20/20 [==============================] - 0s 8ms/step - loss: 10.5483 - accuracy: 0.5533 - val_loss: 10.5691 - val_accuracy: 0.5501
# Epoch 12/100
# 20/20 [==============================] - 0s 9ms/step - loss: 10.4986 - accuracy: 0.5544 - val_loss: 10.5365 - val_accuracy: 0.5511
# Epoch 13/100
# 20/20 [==============================] - 0s 7ms/step - loss: 10.4426 - accuracy: 0.5550 - val_loss: 10.4850 - val_accuracy: 0.5520
# Epoch 14/100
# 20/20 [==============================] - 0s 7ms/step - loss: 10.3687 - accuracy: 0.5556 - val_loss: 10.4076 - val_accuracy: 0.5528
# Epoch 15/100
# 20/20 [==============================] - 0s 8ms/step - loss: 10.3307 - accuracy: 0.5563 - val_loss: 10.4476 - val_accuracy: 0.5534
# Epoch 16/100
# 20/20 [==============================] - 0s 7ms/step - loss: 10.3595 - accuracy: 0.5564 - val_loss: 10.4524 - val_accuracy: 0.5539
# Epoch 17/100
# 20/20 [==============================] - 0s 7ms/step - loss: 10.3717 - accuracy: 0.5565 - val_loss: 10.4639 - val_accuracy: 0.5540
# Epoch 18/100
# 20/20 [==============================] - 0s 7ms/step - loss: 10.3797 - accuracy: 0.5566 - val_loss: 10.4605 - val_accuracy: 0.5541
# Epoch 19/100
# 20/20 [==============================] - 0s 8ms/step - loss: 10.3805 - accuracy: 0.5568 - val_loss: 10.4537 - val_accuracy: 0.5543
# Epoch 20/100
# 20/20 [==============================] - 0s 7ms/step - loss: 10.3726 - accuracy: 0.5570 - val_loss: 10.4429 - val_accuracy: 0.5545
# Epoch 21/100
# 20/20 [==============================] - 0s 7ms/step - loss: 10.3717 - accuracy: 0.5571 - val_loss: 10.4436 - val_accuracy: 0.5546
# Epoch 22/100
# 20/20 [==============================] - 0s 7ms/step - loss: 10.3693 - accuracy: 0.5572 - val_loss: 10.4368 - val_accuracy: 0.5547
# Epoch 23/100
# 20/20 [==============================] - 0s 7ms/step - loss: 10.3665 - accuracy: 0.5573 - val_loss: 10.4259 - val_accuracy: 0.5549
# Epoch 24/100
# 20/20 [==============================] - 0s 8ms/step - loss: 10.3600 - accuracy: 0.5574 - val_loss: 10.4063 - val_accuracy: 0.5550
# Epoch 25/100
# 20/20 [==============================] - 0s 7ms/step - loss: 10.3515 - accuracy: 0.5575 - val_loss: 10.3968 - val_accuracy: 0.5551
# Epoch 26/100
# 20/20 [==============================] - 0s 11ms/step - loss: 10.3453 - accuracy: 0.5576 - val_loss: 10.3812 - val_accuracy: 0.5551
# Epoch 27/100
# 20/20 [==============================] - 0s 11ms/step - loss: 10.3351 - accuracy: 0.5577 - val_loss: 10.3615 - val_accuracy: 0.5551
# Epoch 28/100
# 20/20 [==============================] - 0s 11ms/step - loss: 10.3261 - accuracy: 0.5577 - val_loss: 10.3547 - val_accuracy: 0.5554
# Epoch 29/100
# 20/20 [==============================] - 0s 13ms/step - loss: 10.3164 - accuracy: 0.5577 - val_loss: 10.3513 - val_accuracy: 0.5554
# Epoch 30/100
# 20/20 [==============================] - 0s 11ms/step - loss: 10.3129 - accuracy: 0.5577 - val_loss: 10.3445 - val_accuracy: 0.5553
# Epoch 31/100
# 20/20 [==============================] - 0s 11ms/step - loss: nan - accuracy: 0.4860 - val_loss: nan - val_accuracy: 0.3610
# Epoch 32/100
# 20/20 [==============================] - 0s 14ms/step - loss: nan - accuracy: 0.3590 - val_loss: nan - val_accuracy: 0.3610
# Epoch 33/100
# 20/20 [==============================] - 0s 11ms/step - loss: nan - accuracy: 0.3590 - val_loss: nan - val_accuracy: 0.3610
# Epoch 34/100
# 20/20 [==============================] - 0s 12ms/step - loss: nan - accuracy: 0.3590 - val_loss: nan - val_accuracy: 0.3610
# Epoch 35/100
# 20/20 [==============================] - 0s 12ms/step - loss: nan - accuracy: 0.3590 - val_loss: nan - val_accuracy: 0.3610
# Epoch 36/100
# 20/20 [==============================] - 0s 12ms/step - loss: nan - accuracy: 0.3590 - val_loss: nan - val_accuracy: 0.3610
# Epoch 37/100
# 20/20 [==============================] - 0s 13ms/step - loss: nan - accuracy: 0.3590 - val_loss: nan - val_accuracy: 0.3610
# Epoch 38/100
# 20/20 [==============================] - 0s 12ms/step - loss: nan - accuracy: 0.3590 - val_loss: nan - val_accuracy: 0.3610
# Epoch 39/100
# 20/20 [==============================] - 0s 14ms/step - loss: nan - accuracy: 0.3590 - val_loss: nan - val_accuracy: 0.3610
# Epoch 40/100
# 20/20 [==============================] - 0s 13ms/step - loss: nan - accuracy: 0.3590 - val_loss: nan - val_accuracy: 0.3610
# Epoch 41/100
# 20/20 [==============================] - 0s 9ms/step - loss: nan - accuracy: 0.3590 - val_loss: nan - val_accuracy: 0.3610
# Epoch 42/100
# 20/20 [==============================] - 0s 7ms/step - loss: nan - accuracy: 0.3590 - val_loss: nan - val_accuracy: 0.3610
# Epoch 43/100
# 20/20 [==============================] - 0s 7ms/step - loss: nan - accuracy: 0.3590 - val_loss: nan - val_accuracy: 0.3610
# Epoch 44/100
# 20/20 [==============================] - 0s 7ms/step - loss: nan - accuracy: 0.3590 - val_loss: nan - val_accuracy: 0.3610
# Epoch 45/100
# 20/20 [==============================] - 0s 7ms/step - loss: nan - accuracy: 0.3590 - val_loss: nan - val_accuracy: 0.3610
# Epoch 46/100
# 20/20 [==============================] - 0s 7ms/step - loss: nan - accuracy: 0.3590 - val_loss: nan - val_accuracy: 0.3610
# Epoch 47/100
# 20/20 [==============================] - 0s 7ms/step - loss: nan - accuracy: 0.3590 - val_loss: nan - val_accuracy: 0.3610
# Epoch 48/100
# 20/20 [==============================] - 0s 7ms/step - loss: nan - accuracy: 0.3590 - val_loss: nan - val_accuracy: 0.3610
# Epoch 49/100
# 20/20 [==============================] - 0s 7ms/step - loss: nan - accuracy: 0.3590 - val_loss: nan - val_accuracy: 0.3610
# Epoch 50/100
# 20/20 [==============================] - 0s 9ms/step - loss: nan - accuracy: 0.3590 - val_loss: nan - val_accuracy: 0.3610
# Epoch 51/100
# 20/20 [==============================] - 0s 8ms/step - loss: nan - accuracy: 0.3590 - val_loss: nan - val_accuracy: 0.3610
# Epoch 52/100
# 20/20 [==============================] - 0s 7ms/step - loss: nan - accuracy: 0.3590 - val_loss: nan - val_accuracy: 0.3610
# Epoch 53/100
# 20/20 [==============================] - 0s 7ms/step - loss: nan - accuracy: 0.3590 - val_loss: nan - val_accuracy: 0.3610
# Epoch 54/100
# 20/20 [==============================] - 0s 7ms/step - loss: nan - accuracy: 0.3590 - val_loss: nan - val_accuracy: 0.3610
# Epoch 55/100
# 20/20 [==============================] - 0s 7ms/step - loss: nan - accuracy: 0.3590 - val_loss: nan - val_accuracy: 0.3610
# Epoch 56/100
# 20/20 [==============================] - 0s 8ms/step - loss: nan - accuracy: 0.3590 - val_loss: nan - val_accuracy: 0.3610
# Epoch 57/100
# 20/20 [==============================] - 0s 8ms/step - loss: nan - accuracy: 0.3590 - val_loss: nan - val_accuracy: 0.3610
# Epoch 58/100
# 20/20 [==============================] - 0s 8ms/step - loss: nan - accuracy: 0.3590 - val_loss: nan - val_accuracy: 0.3610
# Epoch 59/100
# 20/20 [==============================] - 0s 7ms/step - loss: nan - accuracy: 0.3590 - val_loss: nan - val_accuracy: 0.3610
# Epoch 60/100
# 20/20 [==============================] - 0s 7ms/step - loss: nan - accuracy: 0.3590 - val_loss: nan - val_accuracy: 0.3610
# Epoch 61/100
# 20/20 [==============================] - 0s 8ms/step - loss: nan - accuracy: 0.3590 - val_loss: nan - val_accuracy: 0.3610
# Epoch 62/100
# 20/20 [==============================] - 0s 8ms/step - loss: nan - accuracy: 0.3590 - val_loss: nan - val_accuracy: 0.3610
# Epoch 63/100
# 20/20 [==============================] - 0s 9ms/step - loss: nan - accuracy: 0.3590 - val_loss: nan - val_accuracy: 0.3610
# Epoch 64/100
# 20/20 [==============================] - 0s 8ms/step - loss: nan - accuracy: 0.3590 - val_loss: nan - val_accuracy: 0.3610
# Epoch 65/100
# 20/20 [==============================] - 0s 7ms/step - loss: nan - accuracy: 0.3590 - val_loss: nan - val_accuracy: 0.3610
# Epoch 66/100
# 20/20 [==============================] - 0s 8ms/step - loss: nan - accuracy: 0.3590 - val_loss: nan - val_accuracy: 0.3610
# Epoch 67/100
# 20/20 [==============================] - 0s 8ms/step - loss: nan - accuracy: 0.3590 - val_loss: nan - val_accuracy: 0.3610
# Epoch 68/100
# 20/20 [==============================] - 0s 7ms/step - loss: nan - accuracy: 0.3590 - val_loss: nan - val_accuracy: 0.3610
# Epoch 69/100
# 20/20 [==============================] - 0s 7ms/step - loss: nan - accuracy: 0.3590 - val_loss: nan - val_accuracy: 0.3610
# Epoch 70/100
# 20/20 [==============================] - 0s 8ms/step - loss: nan - accuracy: 0.3590 - val_loss: nan - val_accuracy: 0.3610
# Epoch 71/100
# 20/20 [==============================] - 0s 8ms/step - loss: nan - accuracy: 0.3590 - val_loss: nan - val_accuracy: 0.3610
# Epoch 72/100
# 20/20 [==============================] - 0s 7ms/step - loss: nan - accuracy: 0.3590 - val_loss: nan - val_accuracy: 0.3610
# Epoch 73/100
# 20/20 [==============================] - 0s 7ms/step - loss: nan - accuracy: 0.3590 - val_loss: nan - val_accuracy: 0.3610
# Epoch 74/100
# 20/20 [==============================] - 0s 7ms/step - loss: nan - accuracy: 0.3590 - val_loss: nan - val_accuracy: 0.3610
# Epoch 75/100
# 20/20 [==============================] - 0s 8ms/step - loss: nan - accuracy: 0.3590 - val_loss: nan - val_accuracy: 0.3610
# Epoch 76/100
# 20/20 [==============================] - 0s 8ms/step - loss: nan - accuracy: 0.3590 - val_loss: nan - val_accuracy: 0.3610
# Epoch 77/100
# 20/20 [==============================] - 0s 7ms/step - loss: nan - accuracy: 0.3590 - val_loss: nan - val_accuracy: 0.3610
# Epoch 78/100
# 20/20 [==============================] - 0s 7ms/step - loss: nan - accuracy: 0.3590 - val_loss: nan - val_accuracy: 0.3610
# Epoch 79/100
# 20/20 [==============================] - 0s 8ms/step - loss: nan - accuracy: 0.3590 - val_loss: nan - val_accuracy: 0.3610
# Epoch 80/100
# 20/20 [==============================] - 0s 8ms/step - loss: nan - accuracy: 0.3590 - val_loss: nan - val_accuracy: 0.3610
# Epoch 81/100
# 20/20 [==============================] - 0s 8ms/step - loss: nan - accuracy: 0.3590 - val_loss: nan - val_accuracy: 0.3610
# Epoch 82/100
# 20/20 [==============================] - 0s 7ms/step - loss: nan - accuracy: 0.3590 - val_loss: nan - val_accuracy: 0.3610
# Epoch 83/100
# 20/20 [==============================] - 0s 8ms/step - loss: nan - accuracy: 0.3590 - val_loss: nan - val_accuracy: 0.3610
# Epoch 84/100
# 20/20 [==============================] - 0s 8ms/step - loss: nan - accuracy: 0.3590 - val_loss: nan - val_accuracy: 0.3610
# Epoch 85/100
# 20/20 [==============================] - 0s 7ms/step - loss: nan - accuracy: 0.3590 - val_loss: nan - val_accuracy: 0.3610
# Epoch 86/100
# 20/20 [==============================] - 0s 9ms/step - loss: nan - accuracy: 0.3590 - val_loss: nan - val_accuracy: 0.3610
# Epoch 87/100
# 20/20 [==============================] - 0s 8ms/step - loss: nan - accuracy: 0.3590 - val_loss: nan - val_accuracy: 0.3610
# Epoch 88/100
# 20/20 [==============================] - 0s 8ms/step - loss: nan - accuracy: 0.3590 - val_loss: nan - val_accuracy: 0.3610
# Epoch 89/100
# 20/20 [==============================] - 0s 8ms/step - loss: nan - accuracy: 0.3590 - val_loss: nan - val_accuracy: 0.3610
# Epoch 90/100
# 20/20 [==============================] - 0s 7ms/step - loss: nan - accuracy: 0.3590 - val_loss: nan - val_accuracy: 0.3610
# Epoch 91/100
# 20/20 [==============================] - 0s 8ms/step - loss: nan - accuracy: 0.3590 - val_loss: nan - val_accuracy: 0.3610
# Epoch 92/100
# 20/20 [==============================] - 0s 8ms/step - loss: nan - accuracy: 0.3590 - val_loss: nan - val_accuracy: 0.3610
# Epoch 93/100
# 20/20 [==============================] - 0s 8ms/step - loss: nan - accuracy: 0.3590 - val_loss: nan - val_accuracy: 0.3610
# Epoch 94/100
# 20/20 [==============================] - 0s 8ms/step - loss: nan - accuracy: 0.3590 - val_loss: nan - val_accuracy: 0.3610
# Epoch 95/100
# 20/20 [==============================] - 0s 9ms/step - loss: nan - accuracy: 0.3590 - val_loss: nan - val_accuracy: 0.3610
# Epoch 96/100
# 20/20 [==============================] - 0s 7ms/step - loss: nan - accuracy: 0.3590 - val_loss: nan - val_accuracy: 0.3610
# Epoch 97/100
# 20/20 [==============================] - 0s 11ms/step - loss: nan - accuracy: 0.3590 - val_loss: nan - val_accuracy: 0.3610
# Epoch 98/100
# 20/20 [==============================] - 0s 16ms/step - loss: nan - accuracy: 0.3590 - val_loss: nan - val_accuracy: 0.3610
# Epoch 99/100
# 20/20 [==============================] - 0s 16ms/step - loss: nan - accuracy: 0.3590 - val_loss: nan - val_accuracy: 0.3610
# Epoch 100/100
# 20/20 [==============================] - 0s 22ms/step - loss: nan - accuracy: 0.3590 - val_loss: nan - val_accuracy: 0.3610

# %%
X_test = X_test.astype(np.float32)
X_test = np.reshape(X_test, (-1, X_train.shape[2]))

# %%
# predicting target attribute on testing dataset
test_results = autoencoder.evaluate(X_test, y_test, verbose=1)
print(f'Test results - Loss: {test_results[0]} - Accuracy: {test_results[1]*100}%')
# Out:
# 929/929 [==============================] - 2s 2ms/step - loss: nan - accuracy: 0.3598
# Test results - Loss: nan - Accuracy: 35.981684923172%

# %%
# Plot of accuracy vs epoch for train and test dataset
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title("Plot of accuracy vs epoch for train and test dataset")
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.show()

# %%
# Plot of loss vs epoch for train and test dataset
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title("Plot of loss vs epoch for train and test dataset")
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper right')
plt.show()
